# %%
import intrinio_sdk

# %%
# obtenir Option_Chain_EOD
from __future__ import print_function
import time
import intrinio_sdk as intrinio
from intrinio_sdk.rest import ApiException

intrinio.ApiClient().set_api_key('OmEyYmEyZjQ0MDg0ZWVmZjI5ZWM2MWYzM2ZmNzVmZDk3')
intrinio.ApiClient().allow_retries(True)

symbol = 'AAPL'
expiration = '2023-01-20'
type = 'put'
include_related_symbols = False

response = intrinio.OptionsApi().get_options_chain_eod(symbol, expiration, type=type, include_related_symbols=include_related_symbols)
print(response)
# Out:
# {'chain': [{'option': {'code': 'AAPL230120P00300000',
#                        'expiration': '2023-01-20',
#                        'strike': 300.0,
#                        'ticker': 'AAPL',
#                        'type': 'put'},
#             'prices': {'ask_high': None,
#                        'ask_low': None,
#                        'bid_high': None,
#                        'bid_low': None,
#                        'close': 165.49,
#                        'close_ask': 163.0,
#                        'close_ask_size': 50,
#                        'close_ask_time': datetime.datetime(2023, 1, 20, 20, 59, 59, 380000, tzinfo=tzutc()),
#                        'close_bid': 161.3,
#                        'close_bid_size': 90,
#                        'close_bid_time': datetime.datetime(2023, 1, 20, 21, 0, 0, 63000, tzinfo=tzutc()),
#                        'close_size': None,
# ...

# %%
# Obtenir Option_Expirations
from __future__ import print_function
import time
import intrinio_sdk as intrinio
from intrinio_sdk.rest import ApiException

intrinio.ApiClient().set_api_key('OmEyYmEyZjQ0MDg0ZWVmZjI5ZWM2MWYzM2ZmNzVmZDk3')
intrinio.ApiClient().allow_retries(True)

symbol = 'MSFT'
after = '2023-01-01'
before = '2023-03-31'
include_related_symbols = True

response = intrinio.OptionsApi().get_options_expirations_eod(symbol, after=after, before=before, include_related_symbols=include_related_symbols)
print(response)
# Out:
# {'expirations': ['2023-03-24',
#                  '2023-03-17',
#                  '2023-03-10',
#                  '2023-03-03',
#                  '2023-02-24',
#                  '2023-02-17',
#                  '2023-02-10',
#                  '2023-02-03',
#                  '2023-01-27',
#                  '2023-01-20',
#                  '2023-01-13',
#                  '2023-01-06']}

# %%
# Out:
# {'expirations': ['2023-01-27', '2023-01-20', '2023-01-13', '2023-01-06']}

# %%
# Out:
# {'chain': [{'option': {'code': 'AAPL230120P00300000',
#                        'expiration': '2023-01-20',
#                        'strike': 300.0,
#                        'ticker': 'AAPL',
#                        'type': 'put'},
#             'prices': {'ask_high': None,
#                        'ask_low': None,
#                        'bid_high': None,
#                        'bid_low': None,
#                        'close': 165.49,
#                        'close_ask': 163.0,
#                        'close_ask_size': 50,
#                        'close_ask_time': datetime.datetime(2023, 1, 20, 20, 59, 59, 380000, tzinfo=tzutc()),
#                        'close_bid': 161.3,
#                        'close_bid_size': 90,
#                        'close_bid_time': datetime.datetime(2023, 1, 20, 21, 0, 0, 63000, tzinfo=tzutc()),
#                        'close_size': None,
# ...

# %%
from __future__ import print_function
import time
import intrinio_sdk as intrinio
from intrinio_sdk.rest import ApiException

intrinio.ApiClient().set_api_key('OmEyYmEyZjQ0MDg0ZWVmZjI5ZWM2MWYzM2ZmNzVmZDk3')
intrinio.ApiClient().allow_retries(True)

identifier = 'AAPL230616P00190000'
#next_page = '~null'

response = intrinio.OptionsApi().get_options_prices_eod(identifier, next_page=next_page, )
print(response)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[50], line 12
#       9 identifier = 'AAPL230616P00190000'
#      10 #next_page = '~null'
# ---> 12 response = intrinio.OptionsApi().get_options_prices_eod(identifier, next_page=next_page, )
#      13 print(response)
#
# File ~\anaconda3\Lib\site-packages\intrinio_sdk\api\options_api.py:1906, in OptionsApi.get_options_prices_eod(self, identifier, **kwargs)
#    1904     return self.get_options_prices_eod_with_http_info(identifier, **kwargs)  # noqa: E501
#    1905 else:
# -> 1906     (data) = self.get_options_prices_eod_with_http_info(identifier, **kwargs)  # noqa: E501
#    1907     return data
#
# File ~\anaconda3\Lib\site-packages\intrinio_sdk\api\options_api.py:1975, in OptionsApi.get_options_prices_eod_with_http_info(self, identifier, **kwargs)
#    1972 # Authentication setting
# ...
