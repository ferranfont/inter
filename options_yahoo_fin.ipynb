# %%
import pandas as pd
from yahoo_fin import options

# %%
options.get_options_chain('AAPL')
# Out:
# {'calls':           Contract Name Last Trade Date (EDT)  Strike  Last Price    Bid  \
#  0   AAPL240426C00100000     4/19/2024 7:04 PM   100.0       65.06  64.60
#  1   AAPL240426C00110000     4/19/2024 3:17 PM   110.0       55.19  54.65
#  2   AAPL240426C00125000     4/19/2024 7:04 PM   125.0       40.08  39.70
#  3   AAPL240426C00130000     4/11/2024 7:18 PM   130.0       44.86  34.70
#  4   AAPL240426C00135000     4/19/2024 4:10 PM   135.0       29.75  29.70
#  5   AAPL240426C00140000     4/19/2024 7:51 PM   140.0       25.30  24.25
#  6   AAPL240426C00145000     4/19/2024 5:11 PM   145.0       20.10  19.70
#  7   AAPL240426C00149000     4/19/2024 7:08 PM   149.0       16.24  15.95
#  8   AAPL240426C00150000     4/19/2024 7:45 PM   150.0       15.18  15.00
#  9   AAPL240426C00155000     4/19/2024 7:46 PM   155.0       10.50  10.25
#  10  AAPL240426C00157500     4/19/2024 7:39 PM   157.5        8.05   7.95
#  11  AAPL240426C00160000     4/19/2024 7:57 PM   160.0        5.90   5.80
# ...

# %%
import pandas as pd

# Assuming options_chain is fetched from your source
options_chain = options.get_options_chain('AAPL')

# Create DataFrames for both calls and puts
calls_df = pd.DataFrame(options_chain['calls'])
puts_df = pd.DataFrame(options_chain['puts'])

calls_df
# Out:
#           Contract Name Last Trade Date (EDT)  Strike  Last Price    Bid  \
# 0   AAPL240426C00100000     4/19/2024 7:04 PM   100.0       65.06  64.60
# 1   AAPL240426C00110000     4/19/2024 3:17 PM   110.0       55.19  54.65
# 2   AAPL240426C00125000     4/19/2024 7:04 PM   125.0       40.08  39.70
# 3   AAPL240426C00130000     4/11/2024 7:18 PM   130.0       44.86  34.70
# 4   AAPL240426C00135000     4/19/2024 4:10 PM   135.0       29.75  29.70
# 5   AAPL240426C00140000     4/19/2024 7:51 PM   140.0       25.30  24.25
# 6   AAPL240426C00145000     4/19/2024 5:11 PM   145.0       20.10  19.70
# 7   AAPL240426C00149000     4/19/2024 7:08 PM   149.0       16.24  15.95
# 8   AAPL240426C00150000     4/19/2024 7:45 PM   150.0       15.18  15.00
# 9   AAPL240426C00155000     4/19/2024 7:46 PM   155.0       10.50  10.25
# 10  AAPL240426C00157500     4/19/2024 7:39 PM   157.5        8.05   7.95
# 11  AAPL240426C00160000     4/19/2024 7:57 PM   160.0        5.90   5.80
# ...

# %%
puts_df
# Out:
#           Contract Name Last Trade Date (EDT)  Strike  Last Price    Bid  \
# 0   AAPL240426P00100000     4/19/2024 7:19 PM   100.0        0.01   0.00
# 1   AAPL240426P00105000     4/19/2024 7:00 PM   105.0        0.01   0.00
# 2   AAPL240426P00110000     4/19/2024 5:41 PM   110.0        0.01   0.00
# 3   AAPL240426P00115000     4/19/2024 7:00 PM   115.0        0.01   0.00
# 4   AAPL240426P00120000     4/19/2024 3:50 PM   120.0        0.01   0.00
# 5   AAPL240426P00125000     4/19/2024 3:52 PM   125.0        0.02   0.01
# 6   AAPL240426P00130000     4/19/2024 4:18 PM   130.0        0.01   0.00
# 7   AAPL240426P00135000     4/19/2024 7:28 PM   135.0        0.02   0.01
# 8   AAPL240426P00140000     4/19/2024 7:43 PM   140.0        0.03   0.02
# 9   AAPL240426P00145000     4/19/2024 7:43 PM   145.0        0.04   0.02
# 10  AAPL240426P00146000     4/19/2024 6:47 PM   146.0        0.05   0.03
# 11  AAPL240426P00147000     4/19/2024 7:59 PM   147.0        0.05   0.04
# ...

# %%
nflx_dates = options.get_puts('AAPL', '12/20/2024') #la fecha tiene que ser en el futuro, no tiene backtest
nflx_dates
# Out:
#           Contract Name Last Trade Date (EDT)  Strike  Last Price     Bid  \
# 0   AAPL241220P00050000     4/17/2024 7:30 PM      50        0.03    0.01
# 1   AAPL241220P00055000     4/19/2024 3:47 PM      55        0.05    0.02
# 2   AAPL241220P00060000     4/18/2024 4:28 PM      60        0.05    0.04
# 3   AAPL241220P00065000     4/19/2024 5:25 PM      65        0.08    0.07
# 4   AAPL241220P00070000     4/19/2024 5:23 PM      70        0.11    0.09
# 5   AAPL241220P00075000     4/19/2024 7:25 PM      75        0.15    0.12
# 6   AAPL241220P00080000     4/19/2024 7:38 PM      80        0.19    0.16
# 7   AAPL241220P00085000     4/17/2024 1:35 PM      85        0.19    0.22
# 8   AAPL241220P00090000     4/19/2024 7:29 PM      90        0.33    0.30
# 9   AAPL241220P00095000     4/18/2024 2:40 PM      95        0.40    0.40
# 10  AAPL241220P00100000     4/19/2024 2:35 PM     100        0.53    0.53
# 11  AAPL241220P00105000     4/19/2024 7:31 PM     105        0.72    0.70
# ...
